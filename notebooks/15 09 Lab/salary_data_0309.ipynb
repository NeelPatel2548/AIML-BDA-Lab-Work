# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import(
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
# Read dataset
df = pd.read_csv("D:\\BDA 20\\AIML-BDA-Lab-Work\\data\\Sep 03 Dataset\\Salary_Data.csv")

# Input and output
x = df[["YearsExperience"]]
y = df[["Salary"]]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)


print("Interception: ", model.intercept_)
print("Slope: ", model.coef_[0])

mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test,y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score: ", r2)
# Out:
# Interception:  [25321.58301178]
# Slope:  [9423.81532303]
# MAE: 6286.453830757749
# MSE: 49830096.85590839
# RMSE: 7059.04362190151
# R2 Score:  0.9024461774180497

# %%
#plot the data and regression line
import matplotlib.pyplot as plt
plt.scatter(x,y, color = "blue", label="Actual data")
plt.plot(x_test,y_pred, color="Red", label= "Regression line")

plt.xlabel("Year of Experenice")
plt.ylabel("Salary")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <h1> Convert coefficents back to original units

# %%
# #convrt coefficient back to org unit
# scaler = StandardScaler()

# original_coefficient = model.coef_ / scaler.scale_

# #calc intercept in org. units

# original_interpreter = (
#     model.intercept_
#     - np.sum(original_coefficient * scaler.mean_)
# )

# print(original_interpreter)
# print(original_coefficient)

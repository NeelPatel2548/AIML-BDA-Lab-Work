# %%
# for below cells parameters are:
#     1. entropy
#     2. 0.65

# # dataset = "Iris Dataset"

import pandas as ps
import numpy as nm
import matplotlib.pyplot as plt

df = ps.read_csv("D:\BDA 20\AIML-BDA-Lab-Work\data\diabetes.csv")
df.head()


# df.info()
# print(df.isnull().sum())

# print("Independent variable, X:")
x = df.iloc[:, 0:8].values  #Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age
# print(x)

# print("Dependent variable, Y:")
y = df.iloc[:, 8].values      #Outcome
# print(y)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    x,y,
    test_size=0.65,
    random_state=45
)

from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train) 
x_test=sc_x.transform(x_test)

# print(x_test)

from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='entropy', random_state=0)

classifier.fit(x_train,y_train)


y_pred = classifier.predict(x_test)        

# print("Actual: ",y_test)
# print("Predicted: ",y_pred)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print("\n\nTrue Pos", cm[0][0])
print("True Neg", cm[0][1])
print("False Pos", cm[1][0])
print("False Neg", cm[1][1])

accuracy = (cm[0][0]  + cm[1][1]) / (cm[0][0]  + cm[1][1] + cm[1][0] + cm[0][1])
print("\nAccuracy - ", accuracy * 100, "%")

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

from sklearn import tree
tree.plot_tree(classifier)
# Out:
# True Pos 260
# True Neg 65
# False Pos 77
# False Neg 98
#
# Accuracy -  71.6 %
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.79       325
#            1       0.60      0.56      0.58       175
#
#     accuracy                           0.72       500
#    macro avg       0.69      0.68      0.68       500
# weighted avg       0.71      0.72      0.71       500
# [Text(0.296875, 0.9583333333333334, 'x[5] <= -0.322\nentropy = 0.931\nsamples = 268\nvalue = [175, 93]'),
#  Text(0.07142857142857142, 0.875, 'x[0] <= -0.385\nentropy = 0.38\nsamples = 95\nvalue = [88.0, 7.0]'),
#  Text(0.1841517857142857, 0.9166666666666667, 'True  '),
#  Text(0.047619047619047616, 0.7916666666666666, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(0.09523809523809523, 0.7916666666666666, 'x[1] <= 0.024\nentropy = 0.624\nsamples = 45\nvalue = [38, 7]'),
#  Text(0.047619047619047616, 0.7083333333333334, 'x[4] <= 1.048\nentropy = 0.216\nsamples = 29\nvalue = [28, 1]'),
#  Text(0.023809523809523808, 0.625, 'entropy = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.07142857142857142, 0.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14285714285714285, 0.7083333333333334, 'x[4] <= 0.574\nentropy = 0.954\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.11904761904761904, 0.625, 'x[7] <= 0.167\nentropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.09523809523809523, 0.5416666666666666, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.14285714285714285, 0.5416666666666666, 'x[6] <= -1.034\nentropy = 0.881\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.11904761904761904, 0.4583333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16666666666666666, 0.4583333333333333, 'x[1] <= 0.472\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.14285714285714285, 0.375, 'x[1] <= 0.289\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11904761904761904, 0.2916666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16666666666666666, 0.2916666666666667, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19047619047619047, 0.375, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.16666666666666666, 0.625, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5223214285714286, 0.875, 'x[1] <= 1.451\nentropy = 1.0\nsamples = 173\nvalue = [87, 86]'),
#  Text(0.4095982142857143, 0.9166666666666667, '  False'),
#  Text(0.49851190476190477, 0.7916666666666666, 'x[1] <= -0.856\nentropy = 0.981\nsamples = 150\nvalue = [87, 63]'),
#  Text(0.23809523809523808, 0.7083333333333334, 'x[6] <= 0.546\nentropy = 0.402\nsamples = 25\nvalue = [23, 2]'),
#  Text(0.21428571428571427, 0.625, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.2619047619047619, 0.625, 'x[6] <= 1.019\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.23809523809523808, 0.5416666666666666, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2857142857142857, 0.5416666666666666, 'x[4] <= -0.456\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2619047619047619, 0.4583333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30952380952380953, 0.4583333333333333, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7589285714285714, 0.7083333333333334, 'x[6] <= 0.755\nentropy = 1.0\nsamples = 125\nvalue = [64, 61]'),
#  Text(0.5892857142857143, 0.625, 'x[1] <= 0.206\nentropy = 0.971\nsamples = 100\nvalue = [60, 40]'),
#  Text(0.4166666666666667, 0.5416666666666666, 'x[7] <= -0.269\nentropy = 0.84\nsamples = 52\nvalue = [38, 14]'),
#  Text(0.35714285714285715, 0.4583333333333333, 'x[7] <= -0.968\nentropy = 0.362\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.3333333333333333, 0.375, 'x[6] <= -0.017\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.30952380952380953, 0.2916666666666667, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.35714285714285715, 0.2916666666666667, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.38095238095238093, 0.375, 'entropy = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.47619047619047616, 0.4583333333333333, 'x[2] <= 0.41\nentropy = 0.999\nsamples = 23\nvalue = [11, 12]'),
#  Text(0.42857142857142855, 0.375, 'x[3] <= 1.356\nentropy = 0.837\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.40476190476190477, 0.2916666666666667, 'x[1] <= -0.706\nentropy = 0.619\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.38095238095238093, 0.20833333333333334, 'x[2] <= -1.716\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.35714285714285715, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.40476190476190477, 0.125, 'x[7] <= 1.258\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.38095238095238093, 0.041666666666666664, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.42857142857142855, 0.041666666666666664, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42857142857142855, 0.20833333333333334, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.4523809523809524, 0.2916666666666667, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5238095238095238, 0.375, 'x[0] <= -0.531\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.5, 0.2916666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5476190476190477, 0.2916666666666667, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7619047619047619, 0.5416666666666666, 'x[4] <= 1.077\nentropy = 0.995\nsamples = 48\nvalue = [22, 26]'),
#  Text(0.6904761904761905, 0.4583333333333333, 'x[5] <= 0.246\nentropy = 0.942\nsamples = 39\nvalue = [14.0, 25.0]'),
#  Text(0.6190476190476191, 0.375, 'x[6] <= -0.155\nentropy = 0.977\nsamples = 17\nvalue = [10, 7]'),
#  Text(0.5952380952380952, 0.2916666666666667, 'x[6] <= -0.558\nentropy = 0.779\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.5714285714285714, 0.20833333333333334, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.6190476190476191, 0.20833333333333334, 'x[6] <= -0.323\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.5952380952380952, 0.125, 'x[1] <= 1.136\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5714285714285714, 0.041666666666666664, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6190476190476191, 0.041666666666666664, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6428571428571429, 0.125, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6428571428571429, 0.2916666666666667, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7619047619047619, 0.375, 'x[6] <= 0.57\nentropy = 0.684\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.7380952380952381, 0.2916666666666667, 'x[3] <= 1.934\nentropy = 0.469\nsamples = 20\nvalue = [2, 18]'),
#  Text(0.7142857142857143, 0.20833333333333334, 'x[7] <= 1.215\nentropy = 0.297\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.6904761904761905, 0.125, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.7380952380952381, 0.125, 'x[5] <= 1.142\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7142857142857143, 0.041666666666666664, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7619047619047619, 0.041666666666666664, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7619047619047619, 0.20833333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7857142857142857, 0.2916666666666667, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8333333333333334, 0.4583333333333333, 'x[6] <= -0.873\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.8095238095238095, 0.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8571428571428571, 0.375, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.9285714285714286, 0.625, 'x[7] <= -0.706\nentropy = 0.634\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.9047619047619048, 0.5416666666666666, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9523809523809523, 0.5416666666666666, 'x[6] <= 3.325\nentropy = 0.426\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.9285714285714286, 0.4583333333333333, 'x[7] <= -0.531\nentropy = 0.267\nsamples = 22\nvalue = [1, 21]'),
#  Text(0.9047619047619048, 0.375, 'x[0] <= 0.344\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8809523809523809, 0.2916666666666667, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9285714285714286, 0.2916666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9523809523809523, 0.375, 'entropy = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.9761904761904762, 0.4583333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5461309523809523, 0.7916666666666666, 'entropy = 0.0\nsamples = 23\nvalue = [0, 23]')]

# %%
# for below cells parameters are:
#     1. entropy
#     2. 0.25

# # dataset = "Iris Dataset"

import pandas as ps
import numpy as nm
import matplotlib.pyplot as plt

df = ps.read_csv("D:\BDA 20\AIML-BDA-Lab-Work\data\diabetes.csv")
df.head()


# df.info()
# print(df.isnull().sum())

# print("Independent variable, X:")
x = df.iloc[:, 0:8].values  #Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age
# print(x)

# print("Dependent variable, Y:")
y = df.iloc[:, 8].values      #Outcome
# print(y)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    x,y,
    test_size=0.25,
    random_state=45
)

from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train) 
x_test=sc_x.transform(x_test)

# print(x_test)

from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='entropy', random_state=0)

classifier.fit(x_train,y_train)


y_pred = classifier.predict(x_test)        

# print("Actual: ",y_test)
# print("Predicted: ",y_pred)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print("\n\nTrue Pos", cm[0][0])
print("True Neg", cm[0][1])
print("False Pos", cm[1][0])
print("False Neg", cm[1][1])

accuracy = (cm[0][0]  + cm[1][1]) / (cm[0][0]  + cm[1][1] + cm[1][0] + cm[0][1])
print("\nAccuracy - ", accuracy * 100, "%")

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

from sklearn import tree
tree.plot_tree(classifier)
# Out:
# True Pos 106
# True Neg 24
# False Pos 31
# False Neg 31
#
# Accuracy -  71.35416666666666 %
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79       130
#            1       0.56      0.50      0.53        62
#
#     accuracy                           0.71       192
#    macro avg       0.67      0.66      0.66       192
# weighted avg       0.71      0.71      0.71       192
# [Text(0.4995833333333333, 0.9705882352941176, 'x[1] <= 0.186\nentropy = 0.941\nsamples = 576\nvalue = [370, 206]'),
#  Text(0.14416666666666667, 0.9117647058823529, 'x[5] <= -0.629\nentropy = 0.697\nsamples = 357\nvalue = [290, 67]'),
#  Text(0.321875, 0.9411764705882353, 'True  '),
#  Text(0.02666666666666667, 0.8529411764705882, 'x[0] <= 1.659\nentropy = 0.075\nsamples = 110\nvalue = [109, 1]'),
#  Text(0.013333333333333334, 0.7941176470588235, 'entropy = 0.0\nsamples = 107\nvalue = [107, 0]'),
#  Text(0.04, 0.7941176470588235, 'x[7] <= -0.106\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.02666666666666667, 0.7352941176470589, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05333333333333334, 0.7352941176470589, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.26166666666666666, 0.8529411764705882, 'x[7] <= -0.406\nentropy = 0.837\nsamples = 247\nvalue = [181, 66]'),
#  Text(0.12, 0.7941176470588235, 'x[5] <= 0.097\nentropy = 0.506\nsamples = 125\nvalue = [111, 14]'),
#  Text(0.08, 0.7352941176470589, 'x[0] <= 0.923\nentropy = 0.139\nsamples = 51\nvalue = [50, 1]'),
#  Text(0.06666666666666667, 0.6764705882352942, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(0.09333333333333334, 0.6764705882352942, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16, 0.7352941176470589, 'x[6] <= 0.07\nentropy = 0.671\nsamples = 74\nvalue = [61, 13]'),
#  Text(0.12, 0.6764705882352942, 'x[2] <= 0.726\nentropy = 0.359\nsamples = 44\nvalue = [41, 3]'),
#  Text(0.10666666666666667, 0.6176470588235294, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(0.13333333333333333, 0.6176470588235294, 'x[5] <= 1.333\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.12, 0.5588235294117647, 'x[7] <= -0.748\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.10666666666666667, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13333333333333333, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14666666666666667, 0.5588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2, 0.6764705882352942, 'x[5] <= 0.217\nentropy = 0.918\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.18666666666666668, 0.6176470588235294, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.21333333333333335, 0.6176470588235294, 'x[1] <= -0.1\nentropy = 0.779\nsamples = 26\nvalue = [20, 6]'),
#  Text(0.2, 0.5588235294117647, 'x[6] <= 0.644\nentropy = 0.937\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.16, 0.5, 'x[6] <= 0.087\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.14666666666666667, 0.4411764705882353, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17333333333333334, 0.4411764705882353, 'x[4] <= 0.624\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.16, 0.38235294117647056, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.18666666666666668, 0.38235294117647056, 'x[1] <= -0.61\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17333333333333334, 0.3235294117647059, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2, 0.3235294117647059, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24, 0.5, 'x[4] <= -0.395\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.22666666666666666, 0.4411764705882353, 'x[7] <= -0.791\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.21333333333333335, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25333333333333335, 0.4411764705882353, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.22666666666666666, 0.5588235294117647, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4033333333333333, 0.7941176470588235, 'x[1] <= -1.215\nentropy = 0.984\nsamples = 122\nvalue = [70, 52]'),
#  Text(0.3466666666666667, 0.7352941176470589, 'x[1] <= -2.902\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.3333333333333333, 0.6764705882352942, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36, 0.6764705882352942, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.46, 0.7352941176470589, 'x[6] <= 0.245\nentropy = 0.998\nsamples = 107\nvalue = [56.0, 51.0]'),
#  Text(0.38666666666666666, 0.6764705882352942, 'x[3] <= 0.46\nentropy = 0.947\nsamples = 74\nvalue = [47, 27]'),
#  Text(0.3466666666666667, 0.6176470588235294, 'x[2] <= 0.701\nentropy = 1.0\nsamples = 41\nvalue = [20, 21]'),
#  Text(0.3333333333333333, 0.5588235294117647, 'x[6] <= -0.275\nentropy = 0.96\nsamples = 34\nvalue = [13, 21]'),
#  Text(0.30666666666666664, 0.5, 'x[6] <= -0.684\nentropy = 0.795\nsamples = 25\nvalue = [6, 19]'),
#  Text(0.29333333333333333, 0.4411764705882353, 'x[1] <= -0.132\nentropy = 0.996\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.26666666666666666, 0.38235294117647056, 'x[1] <= -0.769\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.25333333333333335, 0.3235294117647059, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.28, 0.3235294117647059, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.32, 0.38235294117647056, 'x[6] <= -1.134\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.30666666666666664, 0.3235294117647059, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3333333333333333, 0.3235294117647059, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.32, 0.4411764705882353, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.36, 0.5, 'x[0] <= 0.776\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.3466666666666667, 0.4411764705882353, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.37333333333333335, 0.4411764705882353, 'x[5] <= 0.261\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.36, 0.38235294117647056, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.38666666666666666, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36, 0.5588235294117647, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.4266666666666667, 0.6176470588235294, 'x[0] <= -0.991\nentropy = 0.684\nsamples = 33\nvalue = [27, 6]'),
#  Text(0.4, 0.5588235294117647, 'x[1] <= 0.011\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.38666666666666666, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.41333333333333333, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4533333333333333, 0.5588235294117647, 'x[4] <= -0.463\nentropy = 0.567\nsamples = 30\nvalue = [26, 4]'),
#  Text(0.44, 0.5, 'x[0] <= 0.481\nentropy = 0.863\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.4266666666666667, 0.4411764705882353, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4533333333333333, 0.4411764705882353, 'x[2] <= 0.502\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.44, 0.38235294117647056, 'x[5] <= 0.406\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.4266666666666667, 0.3235294117647059, 'x[6] <= -0.222\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.41333333333333333, 0.2647058823529412, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44, 0.2647058823529412, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4533333333333333, 0.3235294117647059, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4666666666666667, 0.38235294117647056, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4666666666666667, 0.5, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.5333333333333333, 0.6764705882352942, 'x[0] <= 0.776\nentropy = 0.845\nsamples = 33\nvalue = [9, 24]'),
#  Text(0.52, 0.6176470588235294, 'x[1] <= 0.059\nentropy = 1.0\nsamples = 18\nvalue = [9, 9]'),
#  Text(0.5066666666666667, 0.5588235294117647, 'x[2] <= 0.204\nentropy = 0.971\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.49333333333333335, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.52, 0.5, 'x[5] <= 0.128\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.5066666666666667, 0.4411764705882353, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5333333333333333, 0.4411764705882353, 'x[7] <= -0.277\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.52, 0.38235294117647056, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5466666666666666, 0.38235294117647056, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5333333333333333, 0.5588235294117647, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5466666666666666, 0.6176470588235294, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.855, 0.9117647058823529, 'x[1] <= 1.428\nentropy = 0.947\nsamples = 219\nvalue = [80, 139]'),
#  Text(0.6772916666666666, 0.9411764705882353, '  False'),
#  Text(0.7366666666666667, 0.8529411764705882, 'x[5] <= -0.25\nentropy = 0.998\nsamples = 159\nvalue = [75, 84]'),
#  Text(0.6466666666666666, 0.7941176470588235, 'x[1] <= 0.76\nentropy = 0.889\nsamples = 49\nvalue = [34, 15]'),
#  Text(0.5866666666666667, 0.7352941176470589, 'x[0] <= -0.697\nentropy = 0.696\nsamples = 32\nvalue = [26, 6]'),
#  Text(0.5733333333333334, 0.6764705882352942, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.6, 0.6764705882352942, 'x[3] <= 0.029\nentropy = 0.845\nsamples = 22\nvalue = [16, 6]'),
#  Text(0.5733333333333334, 0.6176470588235294, 'x[2] <= 0.204\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.56, 0.5588235294117647, 'x[1] <= 0.377\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.5466666666666666, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5733333333333334, 0.5, 'x[0] <= 0.334\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.56, 0.4411764705882353, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5866666666666667, 0.4411764705882353, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5866666666666667, 0.5588235294117647, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.6266666666666667, 0.6176470588235294, 'x[4] <= 0.462\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.6133333333333333, 0.5588235294117647, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.64, 0.5588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7066666666666667, 0.7352941176470589, 'x[7] <= 1.734\nentropy = 0.998\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.6933333333333334, 0.6764705882352942, 'x[7] <= 0.664\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.68, 0.6176470588235294, 'x[0] <= -0.402\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.6666666666666666, 0.5588235294117647, 'x[5] <= -0.389\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6533333333333333, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.68, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6933333333333334, 0.5588235294117647, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7066666666666667, 0.6176470588235294, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.72, 0.6764705882352942, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8266666666666667, 0.7941176470588235, 'x[4] <= 2.11\nentropy = 0.953\nsamples = 110\nvalue = [41, 69]'),
#  Text(0.8133333333333334, 0.7352941176470589, 'x[6] <= -0.172\nentropy = 0.915\nsamples = 103\nvalue = [34, 69]'),
#  Text(0.76, 0.6764705882352942, 'x[4] <= 0.907\nentropy = 0.999\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.7333333333333333, 0.6176470588235294, 'x[5] <= 1.718\nentropy = 0.989\nsamples = 41\nvalue = [18.0, 23.0]'),
#  Text(0.72, 0.5588235294117647, 'x[1] <= 0.266\nentropy = 1.0\nsamples = 36\nvalue = [18, 18]'),
#  Text(0.7066666666666667, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7333333333333333, 0.5, 'x[2] <= -0.094\nentropy = 0.994\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.72, 0.4411764705882353, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7466666666666667, 0.4411764705882353, 'x[6] <= -0.976\nentropy = 0.999\nsamples = 29\nvalue = [15.0, 14.0]'),
#  Text(0.7333333333333333, 0.38235294117647056, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.76, 0.38235294117647056, 'x[6] <= -0.763\nentropy = 0.983\nsamples = 26\nvalue = [15.0, 11.0]'),
#  Text(0.7466666666666667, 0.3235294117647059, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7733333333333333, 0.3235294117647059, 'x[7] <= 0.792\nentropy = 1.0\nsamples = 22\nvalue = [11, 11]'),
#  Text(0.7466666666666667, 0.2647058823529412, 'x[6] <= -0.646\nentropy = 0.954\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.7333333333333333, 0.20588235294117646, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.76, 0.20588235294117646, 'x[6] <= -0.318\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.7466666666666667, 0.14705882352941177, 'x[4] <= 0.295\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.7333333333333333, 0.08823529411764706, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.76, 0.08823529411764706, 'x[0] <= 0.187\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7466666666666667, 0.029411764705882353, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7733333333333333, 0.029411764705882353, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7733333333333333, 0.14705882352941177, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8, 0.2647058823529412, 'x[3] <= 1.077\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.7866666666666666, 0.20588235294117646, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8133333333333334, 0.20588235294117646, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7466666666666667, 0.5588235294117647, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7866666666666666, 0.6176470588235294, 'x[2] <= -0.392\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.7733333333333333, 0.5588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.5588235294117647, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.8666666666666667, 0.6764705882352942, 'x[7] <= 0.964\nentropy = 0.612\nsamples = 53\nvalue = [8, 45]'),
#  Text(0.8533333333333334, 0.6176470588235294, 'x[2] <= -0.392\nentropy = 0.732\nsamples = 39\nvalue = [8.0, 31.0]'),
#  Text(0.84, 0.5588235294117647, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.8666666666666667, 0.5588235294117647, 'x[2] <= -0.219\nentropy = 0.85\nsamples = 29\nvalue = [8, 21]'),
#  Text(0.8533333333333334, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.88, 0.5, 'x[2] <= 0.204\nentropy = 0.764\nsamples = 27\nvalue = [6, 21]'),
#  Text(0.8666666666666667, 0.4411764705882353, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8933333333333333, 0.4411764705882353, 'x[1] <= 1.062\nentropy = 0.863\nsamples = 21\nvalue = [6, 15]'),
#  Text(0.88, 0.38235294117647056, 'x[1] <= 0.982\nentropy = 0.937\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.8666666666666667, 0.3235294117647059, 'x[3] <= 0.522\nentropy = 0.837\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.8533333333333334, 0.2647058823529412, 'x[2] <= 0.8\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.84, 0.20588235294117646, 'x[0] <= -0.108\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.8266666666666667, 0.14705882352941177, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8533333333333334, 0.14705882352941177, 'x[1] <= 0.314\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.84, 0.08823529411764706, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8666666666666667, 0.08823529411764706, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8666666666666667, 0.20588235294117646, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.88, 0.2647058823529412, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8933333333333333, 0.3235294117647059, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9066666666666666, 0.38235294117647056, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.88, 0.6176470588235294, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.84, 0.7352941176470589, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.9733333333333334, 0.8529411764705882, 'x[7] <= 2.846\nentropy = 0.414\nsamples = 60\nvalue = [5, 55]'),
#  Text(0.96, 0.7941176470588235, 'x[7] <= 0.108\nentropy = 0.358\nsamples = 59\nvalue = [4, 55]'),
#  Text(0.9466666666666667, 0.7352941176470589, 'x[6] <= -0.458\nentropy = 0.567\nsamples = 30\nvalue = [4, 26]'),
#  Text(0.92, 0.6764705882352942, 'x[6] <= -0.633\nentropy = 0.954\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.9066666666666666, 0.6176470588235294, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9333333333333333, 0.6176470588235294, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9733333333333334, 0.6764705882352942, 'x[4] <= 4.971\nentropy = 0.267\nsamples = 22\nvalue = [1, 21]'),
#  Text(0.96, 0.6176470588235294, 'entropy = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.9866666666666667, 0.6176470588235294, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9733333333333334, 0.7352941176470589, 'entropy = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.9866666666666667, 0.7941176470588235, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
# for below cells parameters are:
#     1. entropy
#     2. 0.2

# # dataset = "Iris Dataset"

import pandas as ps
import numpy as nm
import matplotlib.pyplot as plt

df = ps.read_csv("D:\BDA 20\AIML-BDA-Lab-Work\data\diabetes.csv")
df.head()


# df.info()
# print(df.isnull().sum())

# print("Independent variable, X:")
x = df.iloc[:, 0:8].values  #Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age
# print(x)

# print("Dependent variable, Y:")
y = df.iloc[:, 8].values      #Outcome
# print(y)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    x,y,
    test_size=0.20,
    random_state=45
)

from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train) 
x_test=sc_x.transform(x_test)

# print(x_test)

from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='entropy', random_state=0)

classifier.fit(x_train,y_train)


y_pred = classifier.predict(x_test)        

# print("Actual: ",y_test)
# print("Predicted: ",y_pred)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print("\n\nTrue Pos", cm[0][0])
print("True Neg", cm[0][1])
print("False Pos", cm[1][0])
print("False Neg", cm[1][1])

accuracy = (cm[0][0]  + cm[1][1]) / (cm[0][0]  + cm[1][1] + cm[1][0] + cm[0][1])
print("\nAccuracy - ", accuracy * 100, "%")

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

from sklearn import tree
tree.plot_tree(classifier)
# Out:
# True Pos 76
# True Neg 28
# False Pos 25
# False Neg 25
#
# Accuracy -  65.5844155844156 %
#               precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74       104
#            1       0.47      0.50      0.49        50
#
#     accuracy                           0.66       154
#    macro avg       0.61      0.62      0.61       154
# weighted avg       0.66      0.66      0.66       154
# [Text(0.4339561855670103, 0.9666666666666667, 'x[1] <= 0.066\nentropy = 0.938\nsamples = 614\nvalue = [396.0, 218.0]'),
#  Text(0.10615335051546392, 0.9, 'x[5] <= -0.621\nentropy = 0.666\nsamples = 351\nvalue = [290.0, 61.0]'),
#  Text(0.2700547680412371, 0.9333333333333333, 'True  '),
#  Text(0.020618556701030927, 0.8333333333333334, 'x[0] <= 1.642\nentropy = 0.073\nsamples = 113\nvalue = [112, 1]'),
#  Text(0.010309278350515464, 0.7666666666666667, 'entropy = 0.0\nsamples = 109\nvalue = [109, 0]'),
#  Text(0.030927835051546393, 0.7666666666666667, 'x[7] <= -0.105\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.020618556701030927, 0.7, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.041237113402061855, 0.7, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.19168814432989692, 0.8333333333333334, 'x[7] <= -0.404\nentropy = 0.815\nsamples = 238\nvalue = [178, 60]'),
#  Text(0.08762886597938144, 0.7666666666666667, 'x[5] <= 1.691\nentropy = 0.552\nsamples = 125\nvalue = [109, 16]'),
#  Text(0.061855670103092786, 0.7, 'x[6] <= 0.072\nentropy = 0.492\nsamples = 121\nvalue = [108, 13]'),
#  Text(0.041237113402061855, 0.6333333333333333, 'x[6] <= -0.659\nentropy = 0.292\nsamples = 78\nvalue = [74, 4]'),
#  Text(0.030927835051546393, 0.5666666666666667, 'x[6] <= -0.699\nentropy = 0.579\nsamples = 29\nvalue = [25, 4]'),
#  Text(0.020618556701030927, 0.5, 'x[1] <= -0.11\nentropy = 0.235\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.010309278350515464, 0.43333333333333335, 'entropy = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.030927835051546393, 0.43333333333333335, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.041237113402061855, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.05154639175257732, 0.5666666666666667, 'entropy = 0.0\nsamples = 49\nvalue = [49, 0]'),
#  Text(0.08247422680412371, 0.6333333333333333, 'x[5] <= 0.099\nentropy = 0.74\nsamples = 43\nvalue = [34, 9]'),
#  Text(0.07216494845360824, 0.5666666666666667, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.09278350515463918, 0.5666666666666667, 'x[5] <= 0.218\nentropy = 0.943\nsamples = 25\nvalue = [16, 9]'),
#  Text(0.08247422680412371, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.10309278350515463, 0.5, 'x[6] <= 0.646\nentropy = 0.845\nsamples = 22\nvalue = [16, 6]'),
#  Text(0.061855670103092786, 0.43333333333333335, 'x[6] <= 0.086\nentropy = 0.592\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.05154639175257732, 0.36666666666666664, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07216494845360824, 0.36666666666666664, 'x[6] <= 0.568\nentropy = 0.391\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.061855670103092786, 0.3, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.08247422680412371, 0.3, 'x[1] <= -0.801\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.07216494845360824, 0.23333333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09278350515463918, 0.23333333333333334, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14432989690721648, 0.43333333333333335, 'x[1] <= -0.094\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.13402061855670103, 0.36666666666666664, 'x[3] <= -0.343\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.12371134020618557, 0.3, 'x[7] <= -0.83\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1134020618556701, 0.23333333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13402061855670103, 0.23333333333333334, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14432989690721648, 0.3, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.15463917525773196, 0.36666666666666664, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1134020618556701, 0.7, 'x[1] <= -0.078\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.10309278350515463, 0.6333333333333333, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.12371134020618557, 0.6333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2957474226804124, 0.7666666666666667, 'x[6] <= 0.45\nentropy = 0.964\nsamples = 113\nvalue = [69, 44]'),
#  Text(0.19974226804123713, 0.7, 'x[1] <= -0.897\nentropy = 0.872\nsamples = 82\nvalue = [58, 24]'),
#  Text(0.15463917525773196, 0.6333333333333333, 'x[1] <= -2.921\nentropy = 0.426\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.14432989690721648, 0.5666666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16494845360824742, 0.5666666666666667, 'x[0] <= 2.08\nentropy = 0.267\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.15463917525773196, 0.5, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.17525773195876287, 0.5, 'x[5] <= -0.082\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.16494845360824742, 0.43333333333333335, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18556701030927836, 0.43333333333333335, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.24484536082474226, 0.6333333333333333, 'x[2] <= -0.095\nentropy = 0.953\nsamples = 59\nvalue = [37, 22]'),
#  Text(0.20618556701030927, 0.5666666666666667, 'x[7] <= -0.318\nentropy = 0.918\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.1958762886597938, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21649484536082475, 0.5, 'x[4] <= -0.337\nentropy = 0.779\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.20618556701030927, 0.43333333333333335, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.2268041237113402, 0.43333333333333335, 'x[0] <= -0.989\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.21649484536082475, 0.36666666666666664, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23711340206185566, 0.36666666666666664, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.28350515463917525, 0.5666666666666667, 'x[0] <= -0.404\nentropy = 0.845\nsamples = 44\nvalue = [32, 12]'),
#  Text(0.25773195876288657, 0.5, 'x[2] <= 0.857\nentropy = 0.954\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.24742268041237114, 0.43333333333333335, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.26804123711340205, 0.43333333333333335, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.30927835051546393, 0.5, 'x[5] <= -0.038\nentropy = 0.711\nsamples = 36\nvalue = [29, 7]'),
#  Text(0.28865979381443296, 0.43333333333333335, 'x[2] <= 0.206\nentropy = 0.98\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.27835051546391754, 0.36666666666666664, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.29896907216494845, 0.36666666666666664, 'x[7] <= -0.148\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.28865979381443296, 0.3, 'x[5] <= -0.383\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.27835051546391754, 0.23333333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.29896907216494845, 0.23333333333333334, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.30927835051546393, 0.3, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.32989690721649484, 0.43333333333333335, 'x[7] <= 0.874\nentropy = 0.414\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.31958762886597936, 0.36666666666666664, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.3402061855670103, 0.36666666666666664, 'x[5] <= 1.171\nentropy = 0.722\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.32989690721649484, 0.3, 'x[1] <= -0.753\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.31958762886597936, 0.23333333333333334, 'x[0] <= 0.765\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.30927835051546393, 0.16666666666666666, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32989690721649484, 0.16666666666666666, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3402061855670103, 0.23333333333333334, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.35051546391752575, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3917525773195876, 0.7, 'x[7] <= 0.874\nentropy = 0.938\nsamples = 31\nvalue = [11, 20]'),
#  Text(0.38144329896907214, 0.6333333333333333, 'x[0] <= -0.989\nentropy = 0.999\nsamples = 23\nvalue = [11, 12]'),
#  Text(0.3711340206185567, 0.5666666666666667, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3917525773195876, 0.5666666666666667, 'x[1] <= -1.202\nentropy = 0.971\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.38144329896907214, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4020618556701031, 0.5, 'x[0] <= 0.765\nentropy = 0.874\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.3917525773195876, 0.43333333333333335, 'x[1] <= -0.062\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.38144329896907214, 0.36666666666666664, 'x[3] <= -0.033\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.3711340206185567, 0.3, 'x[5] <= -0.02\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.36082474226804123, 0.23333333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38144329896907214, 0.23333333333333334, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3917525773195876, 0.3, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4020618556701031, 0.36666666666666664, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.41237113402061853, 0.43333333333333335, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4020618556701031, 0.6333333333333333, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.7617590206185567, 0.9, 'x[1] <= 1.223\nentropy = 0.973\nsamples = 263\nvalue = [106, 157]'),
#  Text(0.5978576030927836, 0.9333333333333333, '  False'),
#  Text(0.6059922680412371, 0.8333333333333334, 'x[5] <= -0.245\nentropy = 0.999\nsamples = 182\nvalue = [95, 87]'),
#  Text(0.4381443298969072, 0.7666666666666667, 'x[7] <= -1.0\nentropy = 0.863\nsamples = 63\nvalue = [45, 18]'),
#  Text(0.42783505154639173, 0.7, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.4484536082474227, 0.7, 'x[6] <= -0.796\nentropy = 0.931\nsamples = 52\nvalue = [34, 18]'),
#  Text(0.422680412371134, 0.6333333333333333, 'x[5] <= -0.339\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.41237113402061853, 0.5666666666666667, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4329896907216495, 0.5666666666666667, 'x[6] <= -0.863\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.422680412371134, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.44329896907216493, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4742268041237113, 0.6333333333333333, 'x[1] <= 0.131\nentropy = 0.984\nsamples = 40\nvalue = [23, 17]'),
#  Text(0.4639175257731959, 0.5666666666666667, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.4845360824742268, 0.5666666666666667, 'x[1] <= 0.773\nentropy = 0.928\nsamples = 35\nvalue = [23, 12]'),
#  Text(0.4639175257731959, 0.5, 'x[6] <= 0.347\nentropy = 0.779\nsamples = 26\nvalue = [20, 6]'),
#  Text(0.4536082474226804, 0.43333333333333335, 'x[5] <= -1.06\nentropy = 0.918\nsamples = 18\nvalue = [12, 6]'),
#  Text(0.44329896907216493, 0.36666666666666664, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4639175257731959, 0.36666666666666664, 'x[5] <= -0.771\nentropy = 0.971\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.4536082474226804, 0.3, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4742268041237113, 0.3, 'x[1] <= 0.484\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.4639175257731959, 0.23333333333333334, 'x[1] <= 0.388\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.4536082474226804, 0.16666666666666666, 'x[3] <= -0.157\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.44329896907216493, 0.1, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4639175257731959, 0.1, 'x[4] <= -0.26\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4536082474226804, 0.03333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4742268041237113, 0.03333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4742268041237113, 0.16666666666666666, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4845360824742268, 0.23333333333333334, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4742268041237113, 0.43333333333333335, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5051546391752577, 0.5, 'x[5] <= -0.301\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.4948453608247423, 0.43333333333333335, 'x[1] <= 1.159\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.4845360824742268, 0.36666666666666664, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.5051546391752577, 0.36666666666666664, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5154639175257731, 0.43333333333333335, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.773840206185567, 0.7666666666666667, 'x[4] <= 2.122\nentropy = 0.982\nsamples = 119\nvalue = [50, 69]'),
#  Text(0.7280927835051546, 0.7, 'x[6] <= 0.116\nentropy = 0.959\nsamples = 110\nvalue = [42, 68]'),
#  Text(0.6675257731958762, 0.6333333333333333, 'x[5] <= 1.24\nentropy = 0.999\nsamples = 60\nvalue = [31.0, 29.0]'),
#  Text(0.6134020618556701, 0.5666666666666667, 'x[7] <= 0.747\nentropy = 0.968\nsamples = 48\nvalue = [29, 19]'),
#  Text(0.5670103092783505, 0.5, 'x[6] <= -0.762\nentropy = 0.874\nsamples = 34\nvalue = [24, 10]'),
#  Text(0.5360824742268041, 0.43333333333333335, 'x[4] <= 0.402\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.5257731958762887, 0.36666666666666664, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5463917525773195, 0.36666666666666664, 'x[1] <= 0.58\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5360824742268041, 0.3, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5567010309278351, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5979381443298969, 0.43333333333333335, 'x[4] <= 0.828\nentropy = 0.75\nsamples = 28\nvalue = [22, 6]'),
#  Text(0.5876288659793815, 0.36666666666666664, 'x[1] <= 0.291\nentropy = 0.863\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.5773195876288659, 0.3, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5979381443298969, 0.3, 'x[2] <= 0.106\nentropy = 0.954\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.5876288659793815, 0.23333333333333334, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6082474226804123, 0.23333333333333334, 'x[0] <= 0.18\nentropy = 0.779\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.5979381443298969, 0.16666666666666666, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.6185567010309279, 0.16666666666666666, 'x[2] <= 0.782\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6082474226804123, 0.1, 'x[6] <= -0.262\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5979381443298969, 0.03333333333333333, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6185567010309279, 0.03333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6288659793814433, 0.1, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6082474226804123, 0.36666666666666664, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6597938144329897, 0.5, 'x[6] <= -0.759\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.6391752577319587, 0.43333333333333335, 'x[2] <= 0.406\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6288659793814433, 0.36666666666666664, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6494845360824743, 0.36666666666666664, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6804123711340206, 0.43333333333333335, 'x[5] <= 0.707\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.6701030927835051, 0.36666666666666664, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6907216494845361, 0.36666666666666664, 'x[7] <= 1.087\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6804123711340206, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7010309278350515, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7216494845360825, 0.5666666666666667, 'x[3] <= 1.822\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.711340206185567, 0.5, 'x[6] <= -0.847\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.7010309278350515, 0.43333333333333335, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7216494845360825, 0.43333333333333335, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.7319587628865979, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.788659793814433, 0.6333333333333333, 'x[7] <= -0.318\nentropy = 0.76\nsamples = 50\nvalue = [11, 39]'),
#  Text(0.7628865979381443, 0.5666666666666667, 'x[2] <= -0.395\nentropy = 0.982\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.7525773195876289, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7731958762886598, 0.5, 'x[5] <= 0.112\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.7525773195876289, 0.43333333333333335, 'x[7] <= -0.404\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.7422680412371134, 0.36666666666666664, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7628865979381443, 0.36666666666666664, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7938144329896907, 0.43333333333333335, 'x[3] <= -0.93\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.7835051546391752, 0.36666666666666664, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8041237113402062, 0.36666666666666664, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8144329896907216, 0.5666666666666667, 'x[5] <= 1.02\nentropy = 0.459\nsamples = 31\nvalue = [3, 28]'),
#  Text(0.8041237113402062, 0.5, 'entropy = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.8247422680412371, 0.5, 'x[5] <= 1.164\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.8144329896907216, 0.43333333333333335, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8350515463917526, 0.43333333333333335, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8195876288659794, 0.7, 'x[2] <= 0.957\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.8092783505154639, 0.6333333333333333, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.8298969072164949, 0.6333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9175257731958762, 0.8333333333333334, 'x[6] <= -0.406\nentropy = 0.573\nsamples = 81\nvalue = [11, 70]'),
#  Text(0.8762886597938144, 0.7666666666666667, 'x[6] <= -0.901\nentropy = 0.837\nsamples = 30\nvalue = [8, 22]'),
#  Text(0.865979381443299, 0.7, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8865979381443299, 0.7, 'x[4] <= -0.006\nentropy = 0.946\nsamples = 22\nvalue = [8, 14]'),
#  Text(0.865979381443299, 0.6333333333333333, 'x[1] <= 2.042\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.8556701030927835, 0.5666666666666667, 'x[0] <= 1.057\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.845360824742268, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.865979381443299, 0.5, 'x[6] <= -0.822\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8556701030927835, 0.43333333333333335, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8762886597938144, 0.43333333333333335, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8762886597938144, 0.5666666666666667, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9072164948453608, 0.6333333333333333, 'x[3] <= -0.25\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.8969072164948454, 0.5666666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9175257731958762, 0.5666666666666667, 'x[5] <= 1.716\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.9072164948453608, 0.5, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.9278350515463918, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9587628865979382, 0.7666666666666667, 'x[4] <= 4.718\nentropy = 0.323\nsamples = 51\nvalue = [3, 48]'),
#  Text(0.9381443298969072, 0.7, 'x[7] <= 2.664\nentropy = 0.146\nsamples = 48\nvalue = [1, 47]'),
#  Text(0.9278350515463918, 0.6333333333333333, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.9484536082474226, 0.6333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.979381443298969, 0.7, 'x[7] <= 1.002\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9690721649484536, 0.6333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9896907216494846, 0.6333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]')]
